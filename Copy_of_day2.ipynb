# %% [markdown]
# <a href="https://colab.research.google.com/github/sheenayoosaf/100-days-of-code/blob/main/Copy_of_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
inputs = [4,5]
weights = [0.1,0.2]
bias = 2

outputs = (inputs[0]*weights[0] + inputs[1]*weights[1] )

print(outputs)
# Out:
# 1.4

# %%
eights = [[0.2, 0.8, -0.5, 1],
 [0.5, -0.91, 0.26, -0.5],
 [-0.26, -0.27, 0.17, 0.87]]

# %%
inputs = [4,3,3,1]

weights = [[0.3, 0.3, 0.5, -1],
 [0.6, 0.23, -0.26, 0.4],
 [-0.3, 0.55, 0.45, 0.93]]


biases = [2, 3, 0.5]

bias1 = 2
bias2 = 3
bias3 = 0.5

outputs = [
 # Neuron 1:
 inputs[0]*weights[0][0] +
 inputs[1]*weights[0][1] +
 inputs[2]*weights[0][2] +
 inputs[3]*weights[0][3] + bias1,
 # Neuron 2:
 inputs[0]*weights[1][0] +
 inputs[1]*weights[1][1] +
 inputs[2]*weights[1][2] +
 inputs[3]*weights[1][3] + bias2,
 # Neuron 3:
 inputs[0]*weights[2][0] +
 inputs[1]*weights[2][1] +
 inputs[2]*weights[2][2] +
 inputs[3]*weights[2][3] + bias3
]

print(outputs)
# Out:
# [4.6, 5.709999999999999, 3.2300000000000004]

# %%
weights = [
    [0.2, 0.6],
    [0.1, 0.8],
    [0.5, 0.3]
]
biases = [0.1, -0.2, 0.05]
inputs = [1.0, 0.5]
layer_output = []
for neuron_weights, neuron_bias in zip(weights, biases):
    neuron_sum = 0
    for i in range(len(inputs)):
        neuron_sum += inputs[i] * neuron_weights[i]
    neuron_sum += neuron_bias

    neuron_output = neuron_sum
    layer_output.append(neuron_output)

print("Layer Output:", layer_output)
# Out:
# Layer Output: [0.6, 0.3, 0.7000000000000001]

# %%
def sigmoid(x):
    return 1 / (1 + math.exp(-x))
    neuron_output = sigmoid(neuron_sum)
    layer_output.append(neuron_output)

print("Layer Output:", layer_output)
# Out:
# Layer Output: [0.6, 0.3, 0.7000000000000001]
