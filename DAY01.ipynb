# %%
# Day 1 — 100 Days of Python Coding Challenge
# This is my first Python program!

print("Hello, Python World! 👋")
print("I'm starting my 100 Days of Python Challenge today.")
# Out:
# Hello, Python World! 👋
# I'm starting my 100 Days of Python Challenge today.

# %%
# Variables
name = "Sheenamol"
days = 100
is_ready = True

print(f"My name is {name}. I'm ready for {days} days of coding: {is_ready}")
# Out:
# My name is Sheenamol. I'm ready for 100 days of coding: True

# %%
# Basic arithmetic
a = 5
b = 3
sum_result = a + b
product_result = a * b

print(f"Sum: {sum_result}, Product: {product_result}")
# Out:
# Sum: 8, Product: 15

# %%
# Lists and for-loops
numbers = [1, 2, 3, 4, 5]
print("Numbers:", numbers)

for n in numbers:
    print(f"{n} squared = {n**2}")
# Out:
# Numbers: [1, 2, 3, 4, 5]
# 1 squared = 1
# 2 squared = 4
# 3 squared = 9
# 4 squared = 16
# 5 squared = 25

# %%
# !pip install ipywidgets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 41.4 MB/s eta 0:00:00
# ...

# %%
from ipywidgets import Button
from IPython.display import display

# Step 2 — Create a button
button = Button(
    description="🖨️ Print Message",
    button_style="success",  # 'success', 'info', 'warning', 'danger' or ''
    tooltip="Click to print",
)

# Step 3 — Define what happens when you click
def on_button_clicked(b):
    print("Hello, Python World! 👋 You clicked the Print button.")

# Step 4 — Link the button to the function
button.on_click(on_button_clicked)

# Step 5 — Display the button
display(button)
# Out:
# Button(button_style='success', description='🖨️ Print Message', style=ButtonStyle(), tooltip='Click to print')
# Hello, Python World! 👋 You clicked the Print button.

# %%
from ipywidgets import Button
from IPython.display import display

# Step 2 — Create a button
button = Button(
    description="🖨️ Print Message",
    button_style="success",  # 'success', 'info', 'warning', 'danger' or ''
    tooltip="Click to print",
)

# Step 3 — Define what happens when you click
def on_button_clicked(b):
    print("Hello, Python World! 👋 You clicked the Print button.")

# Step 4 — Link the button to the function
button.on_click(on_button_clicked)

# Step 5 — Display the button
display(button)
# Out:
# Button(button_style='success', description='🖨️ Print Message', style=ButtonStyle(), tooltip='Click to print')
# Hello, Python World! 👋 You clicked the Print button.
